# %%
import matplotlib.pyplot as plt

# Data for Median Household Income
years = [2023, 2024, 2025, 2026, 2027, 2028]
income = [72.7, 76.3, 79.8, 83.1, 86.1, 89.0]

# Median Household Income bar chart
plt.figure(figsize=(10, 6))
plt.bar(years, income, color='lightgreen')
plt.title('Median Household Income in Odessa (2023-2028)')
plt.xlabel('Year')
plt.ylabel('Income ($ thousands)')
plt.xticks(years)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.text(0.5, -0.1, "Source: Moody's Analytics", ha='center', va='top', transform=plt.gca().transAxes)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Unemployment Rate
years = [2023, 2024, 2025, 2026, 2027, 2028]
unemployment_rate = [3.4, 3.2, 3.1, 3.0, 3.1, 3.1]

# Unemployment Rate bar chart
plt.figure(figsize=(10, 6))
plt.bar(years, unemployment_rate, color='lightcoral')
plt.title('Unemployment Rate in Odessa (2023-2028)')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
plt.xticks(years)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.text(0.5, -0.1, "Source: Moody's Analytics", ha='center', va='top', transform=plt.gca().transAxes)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Gross Metro Product
years = [2023, 2024, 2025, 2026, 2027, 2028]
gmp = [12.4, 12.7, 13.0, 13.3, 13.6, 13.9]

# Gross Metro Product bar chart
plt.figure(figsize=(10, 6))
plt.bar(years, gmp, color='lightsalmon')
plt.title('Gross Metro Product in Odessa (2023-2028)')
plt.xlabel('Year')
plt.ylabel('Gross Metro Product (C17$ billion)')
plt.xticks(years)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.text(0.5, -0.1, "Source: Moody's Analytics", ha='center', va='top', transform=plt.gca().transAxes)
plt.show()
